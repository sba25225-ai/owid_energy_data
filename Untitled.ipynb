# %% [markdown]
# ## Data Loading
# importing libraries required for data loading. inspection and basic visualisation

# %%
import pandas as pd
import numpy as np

df=pd.read_csv("owid-energy-data.csv")
df.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %%
df.shape
# Out:
# (23195, 130)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23195 entries, 0 to 23194
# Columns: 130 entries, country to wind_share_energy
# dtypes: float64(127), int64(1), object(2)
# memory usage: 23.0+ MB

# %%
df["country"].unique()
# Out:
# array(['ASEAN (Ember)', 'Afghanistan', 'Africa', 'Africa (EI)',
#        'Africa (EIA)', 'Africa (Ember)', 'Africa (Shift)', 'Albania',
#        'Algeria', 'American Samoa', 'Angola', 'Antarctica',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Asia (Ember)', 'Asia Pacific (EI)', 'Asia and Oceania (EIA)',
#        'Asia and Oceania (Shift)', 'Australia',
#        'Australia and New Zealand (EIA)', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'CIS (EI)', 'Cambodia', 'Cameroon', 'Canada',
#        'Cape Verde', 'Cayman Islands', 'Central African Republic',
#        'Central America (EI)', 'Central and South America (EIA)',
# ...

# %% [markdown]
# ## Initial Data Inspection
# The dataset contains energy data for many countries starting from 1900.
# At first look, basic economic data is mostly available, but many energy variables have missing values, especially in early years.

# %%
df_ie_fr=df[df["country"].isin(["Ireland", "France"])]
df_ie_fr.shape
# Out:
# (250, 130)

# %% [markdown]
# ## Country Selection
# Ireland was chosen as the main country, as required by the assignment.
# France was selected for comparison because it is a larger EU country with a different energy structure.

# %%
df_ie_fr["country"].unique()
# Out:
# array(['France', 'Ireland'], dtype=object)

# %%
df_ie_fr["year"].min(), df_ie_fr["year"].max()
# Out:
# (1900, 2024)

# %%
missing_pct = (df_ie_fr.isnull().sum() / len(df_ie_fr)) * 100
missing_pct.sort_values()
# Out:
# country                      0.0
# year                         0.0
# iso_code                     0.0
# coal_prod_per_capita         6.4
# coal_production              6.4
#                             ...
# nuclear_cons_change_pct     76.4
# biofuel_cons_change_pct     79.6
# carbon_intensity_elec       80.0
# greenhouse_gas_emissions    80.0
# solar_cons_change_pct       81.2
# Length: 130, dtype: float64

# %% [markdown]
# ## Handling Missing Data
# Some energy data is missing in early years, especially before 1970.
# this is common in old datasets
# To keep the analysis clear and reliable, data before 1970 is not used.

# %%
df_ie_fr.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec',
#        'wind_share_energy'],
#       dtype='object', length=130)

# %% [markdown]
# ## To make the data simple, we chose important columns about energy for Ireland and France and put them into a new DataFrame

# %%
cols = ["country", "year", "population", "gdp", "primary_energy_consumption", "renewables_share_energy", "wind_share_energy"]

df_energy = df_ie_fr[cols]
df_energy.head()
# Out:
#      country  year  population           gdp  primary_energy_consumption  \
# 7625  France  1900  40019136.0  1.861012e+11                         NaN
# 7626  France  1901  40067484.0  1.830832e+11                         NaN
# 7627  France  1902  40116538.0  1.800736e+11                         NaN
# 7628  France  1903  40166299.0  1.840672e+11                         NaN
# 7629  France  1904  40216118.0  1.854181e+11                         NaN
#
#       renewables_share_energy  wind_share_energy
# 7625                      NaN                NaN
# 7626                      NaN                NaN
# 7627                      NaN                NaN
# 7628                      NaN                NaN
# 7629                      NaN                NaN

# %%
df_energy.isnull().sum()
# Out:
# country                         0
# year                            0
# population                     50
# gdp                            24
# primary_energy_consumption    130
# renewables_share_energy       130
# wind_share_energy             130
# dtype: int64

# %%
df_energy = df_energy[df_energy["year"] > 1970]

# %% [markdown]
# ## i chosed the countries and variables, and used data after 1970 only, becouse before this date not correct data

# %%
df_energy.isnull().sum()
# Out:
# country                       0
# year                          0
# population                    0
# gdp                           4
# primary_energy_consumption    0
# renewables_share_energy       0
# wind_share_energy             0
# dtype: int64

# %%
df_energy["population"] = df_energy["population"].fillna(df_energy["population"].mean())
df_energy["gdp"] = df_energy["gdp"].fillna(df_energy["gdp"].mean())
df_energy["primary_energy_consumption"] = df_energy["primary_energy_consumption"].fillna(df_energy["primary_energy_consumption"].mean())
df_energy["renewables_share_energy"] = df_energy["renewables_share_energy"].fillna(df_energy["renewables_share_energy"].mean())
df_energy["wind_share_energy"] = df_energy["wind_share_energy"].fillna(df_energy["wind_share_energy"].mean())

df_energy.isnull().sum()
# Out:
# country                       0
# year                          0
# population                    0
# gdp                           0
# primary_energy_consumption    0
# renewables_share_energy       0
# wind_share_energy             0
# dtype: int64

# %% [markdown]
# ## To understand the data i did a simple exploratary analisys. i used scatter plots to se how energy consumpion changes over time in 2 countries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_fr = df_energy[df_energy["country"] == "France"]
df_ie = df_energy[df_energy["country"] == "Ireland"]

plt.figure(figsize=(8,5))
plt.scatter(df_fr["year"], df_fr["primary_energy_consumption"], label="France")
plt.scatter(df_ie["year"], df_ie["primary_energy_consumption"], label="Ireland")
plt.xlabel("Year")
plt.ylabel("Primary Energy Consumption")
plt.title("Primary Energy Consumption: Ireland vs France")
plt.legend()
plt.show()

# %% [markdown]
# ## The first scatter plot shows a big difference in energy use between Ireland and France
# because France uses much more energy, it is hard to see details for both countries on one plot
#
# thats why, i separate them to analyse each country clearly.

# %%
plt.figure(figsize=(8,5))
plt.scatter(
    df_energy[df_energy["country"] == "France"]["year"],
    df_energy[df_energy["country"] == "France"]["primary_energy_consumption"]
)
plt.xlabel("Year")
plt.ylabel("Primary Energy Consumption")
plt.title("Primary Energy Consumption - France")
plt.show()

plt.figure(figsize=(8,5))
plt.scatter(
    df_energy[df_energy["country"] == "Ireland"]["year"],
    df_energy[df_energy["country"] == "Ireland"]["primary_energy_consumption"]
)
plt.xlabel("Year")
plt.ylabel("Primary Energy Consumption")
plt.title("Primary Energy Consumption - Ireland")
plt.show()

# %% [markdown]
# ## Now i show energy consumption for each country separetly and difference becomes clear. France uses much more (above 3000 twh) per year than Ireland (below 200/year), because France has a larger populatuion than ireland, more factories a bigger territory, and more regions that need heating in winter

# %%
plt.figure(figsize=(8,5))
plt.scatter(df_fr["year"], df_fr["renewables_share_energy"])
plt.xlabel("Year")
plt.ylabel("Renewables Share Energy (%)")
plt.title("Renewables Share Energy - France")

plt.figure(figsize=(8,5))
plt.scatter(df_ie["year"], df_ie["renewables_share_energy"])
plt.xlabel("Year")
plt.ylabel("Renewables Share Energy (%)")
plt.title("Renewables Share Energy – Ireland")

plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df_fr["year"], df_fr["wind_share_energy"])
plt.xlabel("Year")
plt.ylabel("Wind Share Energy (%)")
plt.title("Wind Share Energy – France")

plt.figure(figsize=(8,5))
plt.scatter(df_ie["year"], df_ie["wind_share_energy"])
plt.xlabel("Year")
plt.ylabel("Wind Share Energy (%)")
plt.title("Wind Share Energy – Ireland")

plt.show()

# %% [markdown]
# ## Comparing wind share energy over time
# Here,
# i show wind energy share over time in France and Ireland using a line chart.

# %%
df_fr = df_energy[df_energy["country"] == "France"]
df_ie = df_energy[df_energy["country"] == "Ireland"]

plt.figure(figsize=(8,5))
plt.plot(df_fr["year"], df_fr["wind_share_energy"], label="France")
plt.plot(df_ie["year"], df_ie["wind_share_energy"], label="Ireland")

plt.xlabel("Year")
plt.ylabel("Wind Share of Energy (%)")
plt.title("Wind Energy Share Over Time: France vs Ireland")
plt.legend()
plt.show()

# %% [markdown]
# ##### Comparison of Renewable Energy Share over Time (Ireland vs France)
#
# In this step, we analyse how the share of renewable energy in total energy consumption has changed over time for Ireland and France.
# This helps us understand ireland shows a much steeper increase in wind energy share after 2000 while France grows slowly

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x="country", y="renewables_share_energy", data=df_energy)
plt.xlabel("Country")
plt.ylabel("Renewables Share of Energy (%)")
plt.title("Renewables Share of Energy (%) by Country")
plt.show()

# %% [markdown]
# ##this boxplot compares renewable energy share, Ireland shows bigger changes than France. Because France has a more stable energy system with a strong nuclear base so changes in renewable energy share happen more slowly and are less variable.

# %% [markdown]
# ## Correlation
# Here, i look at how energy and economic variables are related in Ireland and France(+1971)using a heatmap.

# %%
numeric_df = df_energy.select_dtypes(include=["number"])

corr = numeric_df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix: Energy & Economic Indicators")
plt.show()

# %% [markdown]
# ## in my dataset population and gdp have positive correlation with energy consumption, its normal for lagrer and rich countries. Wind is a big part of renewable energy, a higher wind energy share means a higher renewable energy share

# %% [markdown]
# ## Handling Missing Data and Data Preparation Decisions
# Some energy data is missing in early years, especially before 1970
# Renewable and wind energy data is often missing, so comparison is not reliable.
# For this reason only data from 1970 onwards is used
# This makes the visual analysis more reliable.

# %% [markdown]
# ## Interactive Data Visualisation (Bokeh)
#
# An interactive chart with Bokeh is used to see renewable energy changes over time in Ireland and France.

# %%
from bokeh.io import output_notebook, output_file, show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool

output_notebook()
output_file("renewables_share_ie_fr.html")

df_fr = df_energy[df_energy["country"] == "France"]
df_ie = df_energy[df_energy["country"] == "Ireland"]

source_fr = ColumnDataSource(df_fr)
source_ie = ColumnDataSource(df_ie)

p = figure(
    title="Renewables Share of Energy (%) — Ireland vs France",
    width=900,
    height=450,
    x_axis_label="Year",
    y_axis_label="Renewables Share of Energy (%)"
)

p.line("year", "renewables_share_energy", source=source_fr, line_width=2, legend_label="France", color="violet")
p.line("year", "renewables_share_energy", source=source_ie, line_width=2, legend_label="Ireland", color="blue")

tooltips = [
    ("Country", "@country"),
    ("Year", "@year"),
    ("Renewables share", "@renewables_share_energy{0.2f}")
]
hover = HoverTool(tooltips=tooltips, mode="vline")
p.add_tools(hover)

p.legend.click_policy = "hide"

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d6fa101e-6f3c-4a2c-a245-d4d18a961842">Loading BokehJS ...</span>
#     </div>
#   <div id="eb8ab223-6f20-459b-9a5e-bde8105a0061" data-root-id="p1007" style="display: contents;"></div>

# %% [markdown]
# ## Conclusion
#
# After 2000, both countries show growth over time.
#
# Ireland shows a sharp increase after a long period of slow change.
#
# France follows a more stable and smooth trend.
#
# This comparison shows that time-based analysis is useful to clearly see how energy trends change over time.
